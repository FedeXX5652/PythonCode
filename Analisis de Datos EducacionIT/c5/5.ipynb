# %%
import pandas as pd
import matplotlib.pyplot as plt

sp = pd.read_csv("StudentsPerformance.csv")
tt = pd.read_csv("titanic.csv")

# %%
print(tt.groupby("Sex").count())
# Out:
#         PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex
# female          314       314     314   314  261    314    314     314   314
# male            577       577     577   577  453    577    577     577   577
#
#         Cabin  Embarked
# Sex
# female     97       312
# male      107       577

# %%
print(tt.groupby("Sex").mean())
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %%
print(tt.groupby("Sex").count()["Age"])
# Out:
# Sex
# female    261
# male      453
# Name: Age, dtype: int64

# %%
print(tt[["Age", "Sex"]].groupby("Sex").mean())
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
print(tt[["Sex", "Age", "Pclass"]].groupby("Sex").max())
# Out:
#          Age  Pclass
# Sex
# female  63.0       3
# male    80.0       3

# %% [markdown]
# ## Ejercicio propuesto en clase:

# %% [markdown]
# Hacer una una función que importe el archivo  StudentsPerformance.csv y realizar:
#
# - guardar el en una variable el dataframe (dt)
# - guardar en la variable shape_date el shape
# - guardar en la variable columns_dt las columnas
# - guardar en la variable tail_dt los ultimos diez objetos
# - guardar en la variable null_sum_df todos los objetos que son de tipo null
# - Selecciona aquellos estudiantes que posean reading and writing score mayor a 85 y guardarlo en la variable students_dt
# - guardar en la variable stads_df la estadistica de df usando df y retornala.

# %%
shape_date = sp.shape
shape_date
# Out:
# (1000, 8)

# %%
columns_dt = sp.head()
columns_dt
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B                         NaN      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
tail_dt = sp.tail(10)
tail_dt
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 990               completed          86             81             75
# ...

# %%
null_sum_df = sp.isna().sum()
null_sum_df
# Out:
# gender                          0
# race/ethnicity                 11
# parental level of education    10
# lunch                           5
# test preparation course        15
# math score                      0
# reading score                   0
# writing score                   0
# dtype: int64

# %%
students_dt = sp[sp["reading"] >= 85 & sp["writing"] >= 85]
students_dt
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'reading'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-3427420dd911> in <module>
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

tt["Age"].plot.hist(bins=100, title="Promedio de edad", legend=True, color="#123456")
# Out:
# <AxesSubplot:title={'center':'Promedio de edad'}, ylabel='Frequency'>

# %%
tt.groupby("Sex").size().plot.bar(title="Promedio de sexo", legend=True, color="#123456")
# Out:
# <AxesSubplot:title={'center':'Promedio de sexo'}, xlabel='Sex'>

# %%
tt.groupby("Sex")["Survived"].sum().plot.bar(title="Promedio de sexo sobreviviente", legend=True, color="#123456")
# Out:
# <AxesSubplot:title={'center':'Promedio de sexo'}, xlabel='Sex'>

# %%
tt.groupby("Sex").size().plot.pie(title="Promedio de sexo")
# Out:
# <AxesSubplot:title={'center':'Promedio de sexo'}, ylabel='None'>

# %%
tt.groupby("Sex")["Survived"].sum().plot.pie(title="Promedio de sexo sobreviviente")
# Out:
# <AxesSubplot:title={'center':'Promedio de sexo sobreviviente'}, ylabel='Survived'>

# %%
tt["Name"].str[-3:]
# Out:
# 0      ris
# 1      er)
# 2      ina
# 3      el)
# 4      nry
#       ...
# 886    zas
# 887    ith
# 888    ie"
# 889    ell
# 890    ick
# Name: Name, Length: 891, dtype: object

# %%
gold = pd.read_csv("BSE.csv")
gold
# Out:
#             Date   Open   High    Low  Close        WAP  No. of Shares  \
# 0     2017-02-06   0.79   0.79   0.76   0.76   0.790000         7430.0
# 1     2017-02-03   0.79   0.79   0.79   0.79   0.790000          310.0
# 2     2017-02-02   0.83   0.83   0.83   0.83   0.830000           75.0
# 3     2017-01-31   0.87   0.87   0.87   0.87   0.870000         1050.0
# 4     2017-01-25   0.91   0.91   0.91   0.91   0.910000          400.0
# ...          ...    ...    ...    ...    ...        ...            ...
# 1655  2009-12-07  65.55  71.00  57.60  65.25  64.071524        42741.0
# 1656  2009-12-04  84.95  84.95  66.30  71.95  73.919145       133820.0
# 1657  2009-12-03  72.00  72.00  65.20  70.80  71.469977        84551.0
# 1658  2009-12-02  60.00  60.00  60.00  60.00  60.000000          250.0
# 1659  2009-12-01  36.00  50.00  36.00  50.00  49.767758        30141.0
#
#       No. of Trades  Total Turnover  Deliverable Quantity  \
# ...

# %%
gold["Date"] = pd.to_datetime(gold["Date"])
print(gold.dtypes)
print(gold.head())
# Out:
# Date                         datetime64[ns]
# Open                                float64
# High                                float64
# Low                                 float64
# Close                               float64
# WAP                                 float64
# No. of Shares                       float64
# No. of Trades                       float64
# Total Turnover                      float64
# Deliverable Quantity                float64
# % Deli. Qty to Traded Qty           float64
# Spread H-L                          float64
# Spread C-O                          float64
# dtype: object
#         Date  Open  High   Low  Close   WAP  No. of Shares  No. of Trades  \
# 0 2017-02-06  0.79  0.79  0.76   0.76  0.79         7430.0            7.0
# 1 2017-02-03  0.79  0.79  0.79   0.79  0.79          310.0            4.0
# 2 2017-02-02  0.83  0.83  0.83   0.83  0.83           75.0            1.0
# 3 2017-01-31  0.87  0.87  0.87   0.87  0.87         1050.0            2.0
# ...

# %%
gold["Date"].min()
# Out:
# Timestamp('2009-12-01 00:00:00')

# %%
gold["Date"].max()
# Out:
# Timestamp('2017-02-06 00:00:00')

# %%
gold["Date"].max() - gold["Date"].min()
# Out:
# Timedelta('2624 days 00:00:00')

# %%
gold.set_index("Date", inplace=True)
gold
# Out:
#              Open   High    Low  Close        WAP  No. of Shares  \
# Date
# 2017-02-06   0.79   0.79   0.76   0.76   0.790000         7430.0
# 2017-02-03   0.79   0.79   0.79   0.79   0.790000          310.0
# 2017-02-02   0.83   0.83   0.83   0.83   0.830000           75.0
# 2017-01-31   0.87   0.87   0.87   0.87   0.870000         1050.0
# 2017-01-25   0.91   0.91   0.91   0.91   0.910000          400.0
# ...           ...    ...    ...    ...        ...            ...
# 2009-12-07  65.55  71.00  57.60  65.25  64.071524        42741.0
# 2009-12-04  84.95  84.95  66.30  71.95  73.919145       133820.0
# 2009-12-03  72.00  72.00  65.20  70.80  71.469977        84551.0
# 2009-12-02  60.00  60.00  60.00  60.00  60.000000          250.0
# 2009-12-01  36.00  50.00  36.00  50.00  49.767758        30141.0
#
#             No. of Trades  Total Turnover  Deliverable Quantity  \
# Date
# 2017-02-06            7.0          5848.0                7430.0
# ...

# %%
gold.index
# Out:
# DatetimeIndex(['2017-02-06', '2017-02-03', '2017-02-02', '2017-01-31',
#                '2017-01-25', '2017-01-24', '2017-01-23', '2017-01-20',
#                '2017-01-19', '2017-01-18',
#                ...
#                '2009-12-14', '2009-12-11', '2009-12-10', '2009-12-09',
#                '2009-12-08', '2009-12-07', '2009-12-04', '2009-12-03',
#                '2009-12-02', '2009-12-01'],
#               dtype='datetime64[ns]', name='Date', length=1660, freq=None)

# %%
gold[gold.index<"2012.6.21"]
# Out:
#              Open   High    Low  Close        WAP  No. of Shares  \
# Date
# 2012-06-20   5.35   5.35   4.54   5.00   5.027588       399779.0
# 2012-06-19   5.48   5.48   5.15   5.26   5.244132       252806.0
# 2012-06-18   5.77   5.77   5.18   5.34   5.318574       235967.0
# 2012-06-15   5.48   5.48   5.04   5.26   5.239426       220356.0
# 2012-06-14   5.55   5.55   4.86   5.27   5.196402       541338.0
# ...           ...    ...    ...    ...        ...            ...
# 2009-12-07  65.55  71.00  57.60  65.25  64.071524        42741.0
# 2009-12-04  84.95  84.95  66.30  71.95  73.919145       133820.0
# 2009-12-03  72.00  72.00  65.20  70.80  71.469977        84551.0
# 2009-12-02  60.00  60.00  60.00  60.00  60.000000          250.0
# 2009-12-01  36.00  50.00  36.00  50.00  49.767758        30141.0
#
#             No. of Trades  Total Turnover  Deliverable Quantity  \
# Date
# 2012-06-20          183.0       2009924.0              191080.0
# ...
