# %% [markdown]
# 1. Crear una columna llamada “SurvivalAge” que sea el producto de la
# columnas “Survived” y “Age”. Hacerlo por operador y por método.
#
# 2. Crear una nueva columna que genere un rango etario para cada
# persona, de modo que las edades entre 0 y 9 generen el número 1,
# entre 10 y 19 el número 2, etc. de modo que los missing values se
# mapeen a cero.
#
# 3. Seleccionar los datos de todas las mujeres de primera clase.
#
# 4. Seleccionar los datos de los varones menores de edad de
# segunda clase.

# %%
#1
import pandas as pd
data = pd.read_csv("titanic_testing.csv")
data["SurvivalAge"] = data["Survived"]*data["Age"]
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  SurvivalAge
# 0      0         A/5 21171   7.2500   NaN        S          0.0
# 1      0          PC 17599  71.2833   C85        C         38.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S         26.0
# 3      0            113803  53.1000  C123        S         35.0
# 4      0            373450   8.0500   NaN        S          0.0

# %%
#2
def func():
    l1=[]
    for x in data["Age"]:
        if x != None:
            l1.append(x%10+1)
        elif pd.isnull(float("Nan")):
            l1.append(0)
    return l1

data["AgeRange"] = func()
data[["AgeRange"]]
# Out:
#      AgeRange
# 0         3.0
# 1         9.0
# 2         7.0
# 3         6.0
# 4         6.0
# ..        ...
# 886       8.0
# 887      10.0
# 888       NaN
# 889       7.0
# 890       3.0
#
# [891 rows x 1 columns]

# %%
#3
data.loc[(data["Pclass"]==1) & (data["Sex"]=="female"), "Survived"]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 31            32         1       1
# 52            53         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
#
#      Parch    Ticket      Fare Cabin Embarked  SurvivalAge  AgeRange
# 1        0  PC 17599   71.2833   C85        C         38.0       9.0
# 3        0    113803   53.1000  C123        S         35.0       6.0
# 11       0    113783   26.5500  C103        S         58.0       9.0
# 31       0  PC 17569  146.5208   B78        C          NaN       NaN
# 52       0  PC 17572   76.7292   D33        C         49.0      10.0
# ..     ...       ...       ...   ...      ...          ...       ...
# 856      1     36928  164.8667   NaN        S         45.0       6.0
# 862      0     17466   25.9292   D17        S         48.0       9.0
# 871      1     11751   52.5542   D35        S         47.0       8.0
# 879      1     11767   83.1583   C50        C         56.0       7.0
# 887      0    112053   30.0000   B42        S         19.0      10.0
#
# [94 rows x 14 columns]

# %%
#4
data.loc[(data["Pclass"]==2) & (data["Sex"]=="male") & (data["Age"]<18)]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 78            79         1       2    Caldwell, Master. Alden Gates  male
# 183          184         1       2        Becker, Master. Richard F  male
# 193          194         1       2       Navratil, Master. Michel M  male
# 340          341         1       2   Navratil, Master. Edmond Roger  male
# 407          408         1       2   Richards, Master. William Rowe  male
# 549          550         1       2   Davies, Master. John Morgan Jr  male
# 755          756         1       2        Hamalainen, Master. Viljo  male
# 791          792         0       2              Gaskell, Mr. Alfred  male
# 827          828         1       2            Mallet, Master. Andre  male
# 831          832         1       2  Richards, Master. George Sibley  male
# 841          842         0       2         Mudd, Mr. Thomas Charles  male
#
#        Age  SibSp  Parch           Ticket     Fare Cabin Embarked  \
# 78    0.83      0      2           248738  29.0000   NaN        S
# 183   1.00      2      1           230136  39.0000    F4        S
# 193   3.00      1      1           230080  26.0000    F2        S
# 340   2.00      1      1           230080  26.0000    F2        S
# 407   3.00      1      1            29106  18.7500   NaN        S
# 549   8.00      1      1       C.A. 33112  36.7500   NaN        S
# 755   0.67      1      1           250649  14.5000   NaN        S
# 791  16.00      0      0           239865  26.0000   NaN        S
# 827   1.00      0      2  S.C./PARIS 2079  37.0042   NaN        C
# 831   0.83      1      1            29106  18.7500   NaN        S
# 841  16.00      0      0      S.O./P.P. 3  10.5000   NaN        S
#
#      SurvivalAge  AgeRange
# 78          0.83      1.83
# 183         1.00      2.00
# 193         3.00      4.00
# 340         2.00      3.00
# 407         3.00      4.00
# 549         8.00      9.00
# 755         0.67      1.67
# 791         0.00      7.00
# 827         1.00      2.00
# 831         0.83      1.83
# 841         0.00      7.00
